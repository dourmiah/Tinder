# %% [markdown]
# # Description Data
#
# Objectifs :
#             - Analyser et comprendre le mieux possible les données
#             - Etablir une/des corrélations entre les variables indépendantes et la variable cible
#             - Déduire une conclusion répondant à la problématique
#
# 1 - Définir target = colonne "Match"
# 2 - Lignes et colonnes
# 3 - Types de variables
# 4 - Nettoyage :
#         - Valeurs manquantes
#         - Doublons
#         - Outliers
#         - Données inutiles
#                 => On peut éliminer du dataset les données redondantes à "match" : dec (décision candidat) et dec_o (décision partenaire du candidat)
#                 => On peut également éliminer du dataset les intérêts/hobbies, ceux-ci étant redondants avec la corrélation d'intérêts (int_corr)
#                 => On peut éliminer tous les résultats rapportés suite au Speed Dating (rencontres, etc...) : On sort du cadre de l'étude !
#                 => On peut éliminer toutes les notes du (de la) candidat(e) (attrx_x, sincx_x, etc...): Elles ne sont pas utiles pour l'analyse
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
# Analyse données :
#
# iid : Id du(de la) candidat(e) au sein de la population totale
# id : Id du(de la) candidate(e) dans la soirée de speed dating
# genre : sexe => 0 = femme, 1 = homme
# idg : Id du(de la) candidat(e) au sein de son genre (hommes, femmes)
# condtn ?
# wave : Evènement de speed dating
# round : Nombre total de rdv dans la soirée de speed dating
# position : Emplacement du rdv dans la salle
# order : Numéro de rdv dans la soirée de speed dating
# partner : Id du(de la) partenaire
# pid : Id du(de la) partenaire dans la soirée de speed dating
# match : Oui / Non => Les deux candidats sont OK (dec = 1 et dec_o = 1) ou KO pour un deuxième RDV
# int_corr : Corrélation entre intérêts/hobbies candidat et partenaire
# samerace : Même race que le partenaire (1 : oui, 0 : non)
#
# age_o : Âge partenaire
# race_o : Race partenaire
#
# pf_o_att : Préférence du (de la) partenaire concernant l'attractivité (note sur 100)
# pf_o_sin : Préférence du (de la) partenintéaire concernant la sincérité (note sur 100)
# pf_o_int : Préférence du (de la) partenaire concernant l'intellignece (note sur 100)
# pf_o_fun : Préférence du (de la) partenaire concernant le plaisir (note sur 100)
# pf_o_amb : Préférence du (de la) partenaire concernant l'ambition (note sur 100)
# pf_o_sha : Préférence du (de la) partenaire concernant les intérêts partagés (note sur 100)
#
# dec_o : Décision du(de la) partenaire pour un deuxième RDV
#
# attr_o : Note attribuée par le (la) partenaire concernant l'attractivité (note sur 10)
# sinc_o : Note attribuée par le (la) partenaire concernant la sincérité (note sur 10)
# intel_o : Note attribuée par le (la) partenaire concernant l'intellignece (note sur 10)
# fun_o : Note attribuée par le (la) partenaire concernant le plaisir (note sur 10)
# amb_o : Note attribuée par le (la) partenaire concernant l'ambition (note sur 10)
# shar_o : Note attribuée par le (la) partenaire concernant les intérêts partagés (note sur 10)
#
# *** Survey filled out by students that are interested in participating in order to register for the event ***
# On en déduit qu'il s'agit essentiellement d'une population "jeune"
#
# like_o : Appréciation générale du (de la) partenaire pour le (la) candidat(e) (note sur 10)
# prob_o : Probabilité exprimée par le (la) partenaire que le (la) candidat(e) accepte un deuxième rdv (note sur 10)
# met_o : Le (la) partenaire a déjà rencontré le (la) candidat(e) avant (1: oui, 2: non)
#
# age : Âge candidat
# field : Domaine d'étude
# field : Code domaine d'étude
# undergra : Ecole fréquentée durant les études
# mn_sat : Median Score SAT (test d'évaluation pour accéder à une grande école) de l'établissement fréquenté
# tuition : Frais de scolarité de l'établissement fréquenté
# race : Race du (de la) candidat(e)
# imprace : Importance pour le (la) candidat(e) que le (la) partenaire soit de la même race (note sur 10)
# imprelig : Importance pour le (la) candidat(e) que le (la) partenaire soit de la même religion (note sur 10)
# from : Ville, pays, région d'origine du (de la) candidat(e)attr
# zipcode : Code postal de la région où le (la) candidat(e) a grandi
# income : Revenu médian des ménages basé sur le code postal
# goal : Objectif du (de la) candidat(e) en participant au Speed Dating
# date : Fréquence des "dates"
# go_out : Fréquence des sorties
# carrer_c : Carrière envisagée par le (la) candidat(e)
# exphappy : Estimation de satisfaction durant la soirée Speed Dating (note sur 10)
# expnum : Estimation par le (la) candidat(e) du nombre de partenaire(s) qui seront intéressé(s) pour un deuxième rendez-vous
#
# dec : Décision du(de la) candidat(e) pour un deuxième RDV
#
# attr : Note attribuée par le (la) candidat(e) concernant l'attractivité (note sur 10)
# sinc : Note attribuée par le (la) candidat(e) concernant la sincérité (note sur 10)
# intel : Note attribuée par le (la) candidat(e) concernant l'intellignece (note sur 10)
# fun : Note attribuée par le (la) candidat(e) concernant le plaisir (note sur 10)
# amb : Note attribuée par le (la) candidat(e) concernant l'ambition (note sur 10)
# shar : Note attribuée par le (la) candidat(e) concernant les intérêts partagés (note sur 10)
#
# like :  Appréciation générale du (de la) candidat(e) pour le (la) partenaire (note sur 10)
# prob : Probabilité exprimée par le (la) candidat(e) que le (la) partenaire accepte un deuxième rdv (note sur 10)
# met : Le (la) candidat(e) a déjà rencontré le (la) partenaire avant (1: oui, 2: non)
# match_es : Estimation par le (la) candidat(e) du nombre de "matchs" qu'il (elle) va obtenir
#
# satis_2 : Niveau de satisfaction générale du (de la) candidat(e) concernant les personnes rencontrées durant la soirée Speed Dating (note sur 10)
# length : Appréciation de la durée des rdv durant la soirée Speed Dating
# numdat_2 : Appréciation du nombre de rdv durant la soirée Speed Dating
#
# you_call : Nombre de personne(s) appelée(s) par le (la) candidat(e) suite à la soirée Speed Dating
# them_call : Nombre de personne(s) ayant appelé le (la) candidat(e) suite à la soirée Speed Dating
# date_3 : En fréquentations avec un des "matchs" ? (1: oui, 2: non)
# numdat_3 : Nombre de "matchs" ayant donné lieu à un rdv par la suite
# num_in_3 : Combien de rdv ?

# %% [markdown]
# # Import librairies

# %%
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.io as pio
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load data file

# %%
data = pd.read_csv("Speed+Dating+Data.csv", encoding='unicode_escape')

# %%
data.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 2      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 3      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 4      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
#
#    fun5_3  amb5_3
# 0     NaN     NaN
# ...

# %%
df = data.copy()

# %%
df.shape
# Out:
# (8378, 195)

# %%
df_all = df['iid'].unique()
len(df_all)
# Out:
# 551

# %%
df_females = df[(df['gender'] == 0)]['iid'].unique()
len(df_females)
# Out:
# 274

# %%
df_males = df[(df['gender'] == 1)]['iid'].unique()
len(df_males)
# Out:
# 277

# %% [markdown]
# Répartition Hommes/Femmes

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_count_female = pd.DataFrame(["Femme" for f in df_females], columns=['genre'])
df_count_male = pd.DataFrame(["Homme" for m in df_males], columns=["genre"])
df_total = pd.concat([df_count_female, df_count_male])

# Calcul de la répartition
distribution = df_total['genre'].value_counts()

# Création du graphique en camembert
labels = distribution.index
sizes = distribution.values

plt.figure(figsize=(6, 6))

# Création du camembert
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, 
        colors=['lightblue', 'lightcoral'], textprops={'fontsize': 12},  # Légendes plus grandes
        pctdistance=0.50)  # Pourcentages un peu plus près du centre

# Titre avec gras et taille plus grande
plt.title('Répartition Hommes/Femmes', fontsize=14)

# Assure que le camembert est en cercle parfait
plt.axis('equal')  

# Affiche le graphique
plt.show()

# %% [markdown]
# Observations :
# Le Dataset contient 8378 lignes et 195 colonnes pour une population de 551 candidat(e)s : 274 femmes et 277 hommes

# %%
df.describe(include='all')
# Out:
#                 iid           id       gender          idg       condtn  \
# count   8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean     283.675937     8.960248     0.500597    17.327166     1.828837
# std      158.583367     5.491329     0.500029    10.940735     0.376673
# min        1.000000     1.000000     0.000000     1.000000     1.000000
# 25%      154.000000     4.000000     0.000000     8.000000     2.000000
# 50%      281.000000     8.000000     1.000000    16.000000     2.000000
# 75%      407.000000    13.000000     1.000000    26.000000     2.000000
# max      552.000000    22.000000     1.000000    44.000000     2.000000
#
#                wave        round     position     positin1        order  ...  \
# ...

# %%
pd.set_option("display.max_row", 8000)
pd.set_option("display.max_column", 200)

# %% [markdown]
# Types in Dataset

# %%
df.dtypes.value_counts()
# Out:
# float64    174
# int64       13
# object       8
# Name: count, dtype: int64

# %% [markdown]
# Observations :
# On a une majorité de valeurs quantitatives (float, integer) dans le dataset.

# %%
df.dtypes
# Out:
# iid           int64
# id          float64
# gender        int64
# idg           int64
# condtn        int64
# wave          int64
# round         int64
# position      int64
# positin1    float64
# order         int64
# partner       int64
# pid         float64
# match         int64
# int_corr    float64
# samerace      int64
# age_o       float64
# race_o      float64
# pf_o_att    float64
# pf_o_sin    float64
# pf_o_int    float64
# pf_o_fun    float64
# pf_o_amb    float64
# pf_o_sha    float64
# dec_o         int64
# attr_o      float64
# sinc_o      float64
# intel_o     float64
# fun_o       float64
# amb_o       float64
# shar_o      float64
# like_o      float64
# prob_o      float64
# met_o       float64
# age         float64
# field        object
# field_cd    float64
# undergra     object
# mn_sat       object
# tuition      object
# race        float64
# imprace     float64
# imprelig    float64
# from         object
# zipcode      object
# income       object
# ...

# %% [markdown]
# On doit convertir les valeurs discrètes (âge, race, etc...) en integer

# %%
X_disc = ["positin1", "age", "race", "age_o", "race_o", "met", "met_o", "goal", 
        "date", "go_out", "career_c", "imprace", "imprelig", "field_cd", "exphappy",
        "like", "prob", "like_o", "prob_o","match_es"]

for col in X_disc:
    df[col] = df[col].fillna(0).astype("int64")

# %% [markdown]
# On convertit les valeurs continues (mn_sat, tuition, income) en float

# %%
X_cont = ["mn_sat", "tuition", "income"]


for col in X_cont:
    df[col] = df[col].str.replace(",","")
    df[col] = df[col].astype("float64")

# %%
df.dtypes.value_counts()
# Out:
# float64    157
# int64       33
# object       5
# Name: count, dtype: int64

# %% [markdown]
# # Nettoyage des données

# %% [markdown]
# Valeurs manquantes

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(df.isna(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# Calcul du pourcentage de valeurs manquantes

# %%
((df.isna().sum() / df.shape[0] )* 100).sort_values(ascending=False)
# Out:
# num_in_3    92.026737
# numdat_3    82.143710
# expnum      78.515159
# sinc7_2     76.665075
# amb7_2      76.665075
# shar7_2     76.438291
# fun7_2      76.318931
# attr7_2     76.318931
# intel7_2    76.318931
# amb5_3      75.936978
# fun7_3      75.936978
# intel7_3    75.936978
# sinc7_3     75.936978
# attr7_3     75.936978
# amb7_3      75.936978
# shar7_3     75.936978
# sinc5_3     75.936978
# shar2_3     75.936978
# fun5_3      75.936978
# intel5_3    75.936978
# attr5_3     75.936978
# fun2_3      64.681308
# attr4_3     64.681308
# sinc4_3     64.681308
# intel4_3    64.681308
# fun4_3      64.681308
# amb4_3      64.681308
# shar4_3     64.681308
# attr2_3     64.681308
# intel2_3    64.681308
# sinc2_3     64.681308
# amb2_3      64.681308
# mn_sat      62.604440
# tuition     57.233230
# date_3      52.566245
# sinc1_3     52.566245
# shar1_3     52.566245
# amb1_3      52.566245
# fun1_3      52.566245
# them_cal    52.566245
# you_call    52.566245
# ...

# %% [markdown]
# Observations :
# La plupart des valeurs manquantes sont dans les colonnes qui contiennent les évaluations du candidat.
# On décide de supprimer ces colonnes, car elles ne sont pas utiles à l'étude
#
# On va conserver dans le dataset les colonnes avec moins de 70 % de valeurs manquantes

# %%
df = df[df.columns[(df.isna().sum() / df.shape[0] * 100) < 70]]

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(df.isna(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# Recherche de doublons

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Observations : Pas de doublons

# %% [markdown]
# Suppression des colonnes inutiles

# %%
# Identité ("iid", "id", "idg", "pid")
df.drop(columns=["iid", "id", "idg", "pid"], inplace=True)

# Colonnes décision ("dec" et "dec_o") : Redondantes avec la colonne "match"
df.drop(columns=["dec", "dec_o"], inplace=True)

# Intérêts/hobbies : redondants avec la corrélation d'intérêts (int_corr)
todrop = ["sports", "tvsports", "exercise", "dining", "museums", "art", "hiking", "gaming", "clubbing", "reading", "tv", "theater", "movies", "concerts", "music", "shopping", "yoga"]
df.drop(columns=todrop, inplace=True)

#  Les données remontées par le candidat suite au Speed Dating (rencontres, appels, etc...) : On sort du cadre de l'étude. Target = "matchs"
#  Colonnes : "satis_2", "length", "numdat_2", "you_call", "them_call", "date_3" 
df.drop(columns=["satis_2", "length", "numdat_2", "you_call", "them_cal", "date_3"], inplace=True)

# Toutes les évaluations du (de la) candidat(e) (attrx_x, sincx_x, etc...): Elles ne sont pas utiles pour l'analyse
todrop = ["pf_o_att", "pf_o_sin", "pf_o_int", "pf_o_fun", "pf_o_amb", "pf_o_sha"] 
criteriastodrop = ["attr", "sinc", "intel", "fun", "amb", "shar"]

for crit in criteriastodrop:
       #    todrop.append(crit)
       #    todrop.append(f"{crit}_o")
          todrop.append(f"{crit}1_s")
          todrop.append(f"{crit}3_s")

          for i in range(1, 6):
                 todrop.append(f"{crit}{i}_1")
                 todrop.append(f"{crit}{i}_2")
                 todrop.append(f"{crit}{i}_3")
df.drop(columns=todrop, inplace=True, errors='ignore')

# %%
df.head()
# Out:
#    gender  condtn  wave  round  position  positin1  order  partner  match  \
# 0       0       1     1     10         7         0      4        1      0
# 1       0       1     1     10         7         0      3        2      0
# 2       0       1     1     10         7         0     10        3      1
# 3       0       1     1     10         7         0      5        4      1
# 4       0       1     1     10         7         0      7        5      1
#
#    int_corr  samerace  age_o  race_o  attr_o  sinc_o  intel_o  fun_o  amb_o  \
# 0      0.14         0     27       2     6.0     8.0      8.0    8.0    8.0
# 1      0.54         0     22       2     7.0     8.0     10.0    7.0    7.0
# 2      0.16         1     22       4    10.0    10.0     10.0   10.0   10.0
# 3      0.61         0     23       2     7.0     8.0      9.0    8.0    9.0
# 4      0.21         0     24       3     8.0     7.0      9.0    6.0    9.0
#
# ...

# %% [markdown]
# # Analyse des données

# %% [markdown]
# Analyse de la target

# %%
# Calcul de la répartition
distribution = df["match"].value_counts(normalize=True)
print(distribution)
# Out:
# match
# 0    0.835283
# 1    0.164717
# Name: proportion, dtype: float64

# %%
distribution = distribution.rename({0: "non match", 1: "match"})

# Création du graphique en camembert
labels = distribution.index
sizes = distribution.values

plt.figure(figsize=(6, 6))

# Création du camembert
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, 
        colors=['lightblue', 'lightcoral'], textprops={'fontsize': 12},  # Légendes plus grandes
        pctdistance=0.50)  # Pourcentages un peu plus près du centre

# Titre avec gras et taille plus grande
plt.title('Répartition match / non match', fontsize=14)

# Assure que le camembert est en cercle parfait
plt.axis('equal')  

# Affiche le graphique
plt.show()

# %% [markdown]
# Observation : On constate que les classes pour la target "match" ne sont pas équilibrées

# %% [markdown]
# Distribution des variables continues

# %%
for col in df.select_dtypes("float"):
    sns.displot(df[col])
# Out:
# c:\Users\Dominique Ourmiah\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
#
# c:\Users\Dominique Ourmiah\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
#
# c:\Users\Dominique Ourmiah\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
#
# c:\Users\Dominique Ourmiah\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
#
# c:\Users\Dominique Ourmiah\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
#
# c:\Users\Dominique Ourmiah\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
#
# c:\Users\Dominique Ourmiah\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
#
# ...

# %% [markdown]
# Analyse de l'âge

# %%
sns.displot(df["age"])
# Out:
# c:\Users\Dominique Ourmiah\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %%
df["age"].value_counts()
# Out:
# age
# 27    1059
# 23     894
# 26     869
# 24     863
# 25     837
# 28     746
# 22     655
# 29     589
# 30     574
# 21     291
# 32     210
# 33     161
# 34     152
# 31     125
# 0       95
# 35      60
# 20      55
# 36      45
# 19      20
# 42      20
# 38      19
# 39      18
# 18      10
# 55       6
# 37       5
# Name: count, dtype: int64

# %%
fig = px.box(df, x = "age")
fig.show()

# %%
((df["age"] == 0).sum() / df.shape[0]) * 100
# Out:
# 1.13392217713058

# %%
((df["age"] > 35).sum() / df.shape[0]) * 100
# Out:
# 1.3487705896395321

# %% [markdown]
# Observations : On constate que le plus gros de l'échantillon se concentre entre 18 et 35 ans. Les âges de 0 an correspondent aux Nan.
# Les 0 an représentent 1,13 % de l'échantillon. Les + 35 ans représentent 1,34 %. On décide de les supprimer.

# %%
print("Nombre de lignes avant suppression Nan : ", df.shape[0])
mask = df["age"] > 0
df = df[mask]
print("Nombre de lignes après suppression Nan : ", df.shape[0])
mask = df["age"] < 35
df = df[mask]
print("Nombre de lignes après suppression + 35 ans : ", df.shape[0])
# Out:
# Nombre de lignes avant suppression Nan :  8378
# Nombre de lignes après suppression Nan :  8283
# Nombre de lignes après suppression + 35 ans :  8110

# %%
print(df["age"].mean())
# Out:
# 26.119852034525277

# %% [markdown]
# Observations : on peut maintenir établir que la moyenne d'âge de la population de l'étude est d'environ 26 ans

# %% [markdown]
# Variables catégorielles

# %%
for col in df.select_dtypes("object"):
    print(f"{col :-<50} {df[col].unique()}")
# Out:
# field--------------------------------------------- ['Law' 'law' 'Economics' 'Masters in Public Administration'
#  'Masters of Social Work&Education' 'Finance' 'Business'
#  'political science' 'money' 'Operations Research' 'TC (Health Ed)'
#  'Psychology' 'social work' 'Social Work' 'Speech Language Pathology'
#  'Speech Languahe Pathology' 'Educational Psychology'
#  'Applied Maths/Econs' 'Mathematics' 'Statistics'
#  'Organizational Psychology' 'Mechanical Engineering' 'Finanace'
#  'Finance&Economics' 'Undergrad - GS' 'Mathematical Finance' 'Medicine'
#  'MBA' 'LAW' 'psychology' 'German Literature'
#  'Business & International Affairs' 'MFA Creative Writing' 'Engineering'
#  'Electrical Engineering' 'Classics' 'Operations Research (SEAS)'
#  'chemistry' 'Journalism' 'Elementary/Childhood Education (MA)'
#  'microbiology' 'Masters of Social Work' 'Communications' 'Marketing'
#  'Chemistry' 'International Educational Development'
# ...

# %% [markdown]
# Population

# %%
print("Nombre de candidat(e)s : ", df_all.shape[0])
print("Nombre de femmes : ", df_females.shape[0])
print("Nombre d'hommes : ", df_males.shape[0])
# Out:
# Nombre de candidat(e)s :  551
# Nombre de femmes :  274
# Nombre d'hommes :  277

# %% [markdown]
# Nous savons que la population est composée de 551 candidat(e) : 274 femmes et 277 hommes

# %% [markdown]
# Corrélation Target - Variables

# %%
# sous-ensemble des matchs = yes
match_yes_df = df[df["match"] == 1]
match_yes_df.head()
# Out:
#     gender  condtn  wave  round  position  positin1  order  partner  match  \
# 2        0       1     1     10         7         0     10        3      1
# 3        0       1     1     10         7         0      5        4      1
# 4        0       1     1     10         7         0      7        5      1
# 8        0       1     1     10         7         0      8        9      1
# 13       0       1     1     10         3         0      1        4      1
#
#     int_corr  samerace  age_o  race_o  attr_o  sinc_o  intel_o  fun_o  amb_o  \
# 2       0.16         1     22       4    10.0    10.0     10.0   10.0   10.0
# 3       0.61         0     23       2     7.0     8.0      9.0    8.0    9.0
# 4       0.21         0     24       3     8.0     7.0      9.0    6.0    9.0
# 8       0.28         0     28       2     7.0     7.0      8.0    8.0    8.0
# 13     -0.21         1     23       2     9.0     9.0      9.0    9.0    9.0
#
# ...

# %%
# sous-ensemble des matchs = no
match_no_df = df[df["match"] == 0]
match_no_df.head()
# Out:
#    gender  condtn  wave  round  position  positin1  order  partner  match  \
# 0       0       1     1     10         7         0      4        1      0
# 1       0       1     1     10         7         0      3        2      0
# 5       0       1     1     10         7         0      6        6      0
# 6       0       1     1     10         7         0      1        7      0
# 7       0       1     1     10         7         0      2        8      0
#
#    int_corr  samerace  age_o  race_o  attr_o  sinc_o  intel_o  fun_o  amb_o  \
# 0      0.14         0     27       2     6.0     8.0      8.0    8.0    8.0
# 1      0.54         0     22       2     7.0     8.0     10.0    7.0    7.0
# 5      0.25         0     25       2     7.0     7.0      8.0    8.0    7.0
# 6      0.34         0     30       2     3.0     6.0      7.0    5.0    8.0
# 7      0.50         0     27       2     6.0     7.0      5.0    6.0    8.0
#
# ...

# %%
# df["age"] < (df["age_o"] + 1)) and (df["age"] > (df["age_o"] -) 1

# %%
# df_2["match"].value_counts()

# %%
plt.figure()
sns.distplot(match_yes_df["int_corr"], label="Match=yes")
sns.distplot(match_no_df["int_corr"], label="Match=no")
plt.legend()
# Out:
# C:\Users\Dominique Ourmiah\AppData\Local\Temp\ipykernel_10440\2920778521.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\Dominique Ourmiah\AppData\Local\Temp\ipykernel_10440\2920778521.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
plt.figure()
sns.distplot(match_yes_df["int_corr"], label="Match=yes")
sns.distplot(match_no_df["int_corr"], label="Match=no")
plt.legend()
# Out:
# C:\Users\Dominique Ourmiah\AppData\Local\Temp\ipykernel_10440\2920778521.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\Dominique Ourmiah\AppData\Local\Temp\ipykernel_10440\2920778521.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# Observations : Pas d'impact des intérêts communs sur un 2ème rdv

# %%
df["samerace_str"] = df["samerace"].astype(str).str.replace("0", "non").str.replace("1", "oui")
df.head()
# Out:
#    gender  condtn  wave  round  position  positin1  order  partner  match  \
# 0       0       1     1     10         7         0      4        1      0
# 1       0       1     1     10         7         0      3        2      0
# 2       0       1     1     10         7         0     10        3      1
# 3       0       1     1     10         7         0      5        4      1
# 4       0       1     1     10         7         0      7        5      1
#
#    int_corr  samerace  age_o  race_o  attr_o  sinc_o  intel_o  fun_o  amb_o  \
# 0      0.14         0     27       2     6.0     8.0      8.0    8.0    8.0
# 1      0.54         0     22       2     7.0     8.0     10.0    7.0    7.0
# 2      0.16         1     22       4    10.0    10.0     10.0   10.0   10.0
# 3      0.61         0     23       2     7.0     8.0      9.0    8.0    9.0
# 4      0.21         0     24       3     8.0     7.0      9.0    6.0    9.0
#
# ...

# %%
pd.crosstab(df["match"], df["samerace_str"])
# Out:
# samerace_str   non   oui
# match
# 0             4108  2662
# 1              785   555

# %% [markdown]
# Observations : Le fait d'avoir une origine ethnique commune n'a pas d'impact sur un deuxième rendez-vous

# %%
plt.figure()
sns.distplot(match_yes_df["imprace"], label="Match=yes", bins=10)
sns.distplot(match_no_df["imprace"], label="Match=no", bins=10)
plt.legend()
# Out:
# C:\Users\Dominique Ourmiah\AppData\Local\Temp\ipykernel_10440\1416102955.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\Dominique Ourmiah\AppData\Local\Temp\ipykernel_10440\1416102955.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# Observations : Pas d'impact d'une origine ethnique commune sur un 2ème rdv

# %%
plt.figure()
sns.distplot(match_yes_df["imprelig"], label="Match=yes", bins=10)
sns.distplot(match_no_df["imprelig"], label="Match=no", bins=10)
plt.legend()
# Out:
# C:\Users\Dominique Ourmiah\AppData\Local\Temp\ipykernel_10440\1413505353.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\Dominique Ourmiah\AppData\Local\Temp\ipykernel_10440\1413505353.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# Observations : Pas d'impact d'une religion commune sur un 2ème rdv

# %%
plt.figure()
sns.distplot(match_yes_df["like"], label="Match=yes", bins=10)
sns.distplot(match_no_df["like"], label="Match=no", bins=10)
plt.legend()
# Out:
# C:\Users\Dominique Ourmiah\AppData\Local\Temp\ipykernel_10440\478064213.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\Dominique Ourmiah\AppData\Local\Temp\ipykernel_10440\478064213.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# Observations : Sans surprise, plus l'appréciation générale du (de la) candidat(e) pour le (la) partenaire est élevée, plus l'obtention d'un 2ème rdv est élevée

# %%
plt.figure()
sns.distplot(match_yes_df["like_o"], label="Match=yes", bins=10)
sns.distplot(match_no_df["like_o"], label="Match=no", bins=10)
plt.legend()
# Out:
# C:\Users\Dominique Ourmiah\AppData\Local\Temp\ipykernel_10440\2427144143.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\Dominique Ourmiah\AppData\Local\Temp\ipykernel_10440\2427144143.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# Observations : Idem concernant l'appréciation du partenaire pour le candidat

# %% [markdown]
# On veut savoir si pour l’obtention d’un 2ème rdv, il est préférable d’être le premier ou le dernier speed dating de quelqu’un

# %% [markdown]
# On va stocker les premiers et les derniers rdv dans deux dataframes différents

# %%
df_first_dates = df[df["order"] == 1]
df_first_dates.head()
# Out:
#     gender  condtn  wave  round  position  positin1  order  partner  match  \
# 6        0       1     1     10         7         0      1        7      0
# 13       0       1     1     10         3         0      1        4      1
# 29       0       1     1     10         9         0      1       10      0
# 37       0       1     1     10         6         0      1        8      0
# 40       0       1     1     10         4         0      1        1      0
#
#     int_corr  samerace  age_o  race_o  attr_o  sinc_o  intel_o  fun_o  amb_o  \
# 6       0.34         0     30       2     3.0     6.0      7.0    5.0    8.0
# 13     -0.21         1     23       2     9.0     9.0      9.0    9.0    9.0
# 29     -0.47         1     24       2     5.0     6.0      8.0    5.0    8.0
# 37      0.15         1     27       2     6.0     7.0      8.0    6.0    6.0
# 40     -0.43         1     27       2     6.0     8.0      8.0    8.0    7.0
#
# ...

# %%
df_last_dates = df[df["round"] == df["order"]]
df_last_dates.head()
# Out:
#     gender  condtn  wave  round  position  positin1  order  partner  match  \
# 2        0       1     1     10         7         0     10        3      1
# 10       0       1     1     10         3         0     10        1      0
# 28       0       1     1     10         9         0     10        9      0
# 36       0       1     1     10         6         0     10        7      0
# 41       0       1     1     10         4         0     10        2      0
#
#     int_corr  samerace  age_o  race_o  attr_o  sinc_o  intel_o  fun_o  amb_o  \
# 2       0.16         1     22       4    10.0    10.0     10.0   10.0   10.0
# 10      0.29         1     27       2     8.0     7.0      6.0    9.0    7.0
# 28     -0.15         1     28       2     7.0     7.0      6.0    8.0    7.0
# 36      0.35         1     30       2     7.0     6.0      3.0    5.0    6.0
# 41      0.00         1     22       2     6.0     7.0     10.0    7.0    6.0
#
# ...

# %%
pd.crosstab(df_first_dates["match"], df_first_dates["order"])
# Out:
# order    1
# match
# 0      408
# 1      122

# %%
pd.crosstab(df_last_dates["match"], df_last_dates["order"])
# Out:
# order  5   6   7   8   9   10  14  15  16  18  19  20  21  22
# match
# 0       5  19   4   4  22  61  32  22  41  51  25  50  38  33
# 1       3   6   2   2   5  21   4   8   9  20   8   7   4  10

# %% [markdown]
# Observations : Pas de corrélation entre l'ordre de passage à un speed dating et un 2ème rdv

# %%
for col in ["attr", "sinc", "intel", "fun",	"amb",	"shar"]:
    plt.figure()
    sns.distplot(match_yes_df[col], label="Match=yes", bins=10)
    sns.distplot(match_no_df[col], label="Match=no", bins=10)
    plt.legend()
# Out:
# C:\Users\Dominique Ourmiah\AppData\Local\Temp\ipykernel_10440\2213386304.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\Dominique Ourmiah\AppData\Local\Temp\ipykernel_10440\2213386304.py:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# ...

# %%
for col in ["attr_o", "sinc_o", "intel_o", "fun_o",	"amb_o", "shar_o"]:
    plt.figure()
    sns.distplot(match_yes_df[col], label="Match=yes", bins=10)
    sns.distplot(match_no_df[col], label="Match=no", bins=10)
    plt.legend()
# Out:
# C:\Users\Dominique Ourmiah\AppData\Local\Temp\ipykernel_10440\2376819934.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\Dominique Ourmiah\AppData\Local\Temp\ipykernel_10440\2376819934.py:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# ...

# %% [markdown]
# Observations : On voit sur les graphiques précédents que les critères qui impactent le plus l'obtention d'un deuxième rdv sont : L'attractivité, le plaisir et les intérets communs.

# %% [markdown]
# Il est intéressant de noter que pour l'int_corr (intérêts communs réels) on n'avait pas relevé d'impact sur le match. On a donc une différence entre les intérêts communs réels (int_corr) et la note attribuée par les candidats sur les intérêts communs (shar)
